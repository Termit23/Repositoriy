# %%
print('А) Список, так как он позволяет добавлять новые данные')
print('B) Словарь, так как позволяет искать значения по ключу')
print('C) Список, так как данные могут изменяться и нам требуется возможность изменять их')
