# %%
name = list(["О","л","е","г"]) 
sort_name = name.copy()
sort_name.sort()
union_list = name[3:] + sort_name
print(name, sort_name, union_list, sep='\n')
# Out:
# ['О', 'л', 'е', 'г']
# ['О', 'г', 'е', 'л']
# ['г', 'О', 'г', 'е', 'л']
