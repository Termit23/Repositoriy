# %%
n = 5
 
factorial = 1
while n > 1:
    factorial *= n
    n -= 1
 
print(factorial)
# Out:
# 120

# %%
n = int ( input ("Введите число n: "))

for a in range (2, n):

    if (n % a) == 0:

        print ("Число ", n, "не простое")

        break

    elif (n // a) :

        print ("Число ", n, " простое!")
# Out:
# Введите число n: 5
# Число  5  простое!
# Число  5  простое!
# Число  5  простое!
