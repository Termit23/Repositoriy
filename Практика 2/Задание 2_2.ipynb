# %%
x=10
y=25
print('Вычисление суммы,разности,произведения и частности:')
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print('Рассчёт значения выражения (x^2+y)(y-1)/x-y+y^2')
print((x**2+y)*(y-1)/x-y+y**2)
# Out:
# Вычисление суммы,разности,произведения и частности:
# 35
# -15
# 250
# 0.4
# Рассчёт значения выражения (x^2+y)(y-1)/x-y+y^2
# 900.0
